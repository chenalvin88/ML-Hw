# %%
# PyTorch
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

# For data preprocess
import numpy as np
import csv
import os

# For plotting
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# %%
net=nn.Sequential(nn.Linear(64, 1))
print(abs(net[0].weight))
print(torch.sum(net[0].weight**2))
# Out:
# tensor([[0.0713, 0.0879, 0.1052, 0.0732, 0.0666, 0.0491, 0.0040, 0.0900, 0.0928,
#          0.1069, 0.0229, 0.0472, 0.0659, 0.1006, 0.0980, 0.0710, 0.1247, 0.0788,
#          0.1057, 0.0061, 0.0681, 0.0419, 0.1057, 0.0527, 0.0507, 0.0390, 0.1248,
#          0.0964, 0.1233, 0.0198, 0.1111, 0.0018, 0.1010, 0.0854, 0.1190, 0.0246,
#          0.1102, 0.0453, 0.0573, 0.0554, 0.0150, 0.1086, 0.1086, 0.0485, 0.1164,
#          0.0843, 0.0993, 0.0383, 0.0348, 0.0009, 0.1162, 0.0113, 0.0271, 0.0257,
#          0.0074, 0.1058, 0.0073, 0.0139, 0.1232, 0.0616, 0.0912, 0.0491, 0.0567,
#          0.0771]], grad_fn=<AbsBackward>)
# tensor(0.3839, grad_fn=<SumBackward0>)

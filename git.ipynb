# %%
# %cd /content/drive/MyDrive/Colab\ Notebooks
# !ls
# Out:
# /content/drive/MyDrive/Colab Notebooks
#  git.ipynb		    'MLSpring2021 - HW2-1.ipynb'
# 'ML2021Spring - HW1.ipynb'   testingpytorch.ipynb

# %% [markdown]
# initialize a local git repository

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/Colab Notebooks/.git/

# %% [markdown]
# Create and name a private git repository. Then we need to add this repository as a remote repository to our git project.

# %%
# !git remote add origin https://chenalvin88:Kypss95131@github.com/chenalvin88/ML-Hw2.git
# !git remote -v
# Out:
# fatal: remote origin already exists.
# origin	https://chenalvin88:Kypss95131@github.com/chenalvin88/ML-Hw1.git (fetch)
# origin	https://chenalvin88:Kypss95131@github.com/chenalvin88/ML-Hw1.git (push)

# %%
# !git remote show origin
# Out:
# * remote origin
#   Fetch URL: https://chenalvin88:Kypss95131@github.com/chenalvin88/ML-Hw1.git
#   Push  URL: https://chenalvin88:Kypss95131@github.com/chenalvin88/ML-Hw1.git
#   HEAD branch: main
#   Remote branches:
#     main   new (next fetch will store in remotes/origin)
#     master tracked
#   Local ref configured for 'git push':
#     master pushes to master (up to date)

# %% [markdown]
# We also need to tell git who we are before committing any changes to our code.

# %%
# !git config --global user.email 'b07202015@g.ntu.edu.tw'
# !git config --global user.name 'b07202015'

# %% [markdown]
# commit for the project

# %%
# !git add .
# !git commit -m 'First commit'
# Out:
# [master 225e8c3] First commit
#  3 files changed, 3 insertions(+), 2 deletions(-)
#  rewrite ML2021Spring - HW1.ipynb (94%)
#  create mode 100644 MLSpring2021 - HW2-1.ipynb
#  rewrite git.ipynb (92%)

# %% [markdown]
# Push to github \
# If the branch doesn’t exist it’ll be automatically created.

# %%
# !git push origin master
# Out:
# Counting objects: 5, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 52.11 KiB | 5.21 MiB/s, done.
# Total 5 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/chenalvin88/ML-Hw1.git
#    7fbf2b5..225e8c3  master -> master

# %% [markdown]
# pull from your remote repository

# %%
#!git pull origin master
